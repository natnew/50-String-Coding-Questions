# %% [markdown]
# <a href="https://colab.research.google.com/github/natnew/50-String-Coding-Questions/blob/main/50_String_Coding_Questions_Using_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #1 - Print A String

# %%
#Message in single quotes
print('Hello World!')

#Message in double quotes
print("Hello World!")
# Out:
# Hello World!
# Hello World!

# %% [markdown]
# #2 - Find A File Using A String

# %%
#import library
import os

# %%
#Get a list of files in the current directory
os.listdir()
# Out:
# ['.config',
#  'Print a file location from a string.txt',
#  'Questions for interview.txt',
#  'sample_data']

# %%
#Find out what the current directory is
os.getcwd()
# Out:
# '/content'

# %%
#Assign text inputs to a variables

text = input("input text : ")

path = input("path : ")


#Create a definition that accepts the inputs and prints out the file location
def getfiles(path):
    f = 0
    os.chdir(path)
    files = os.listdir()
    # print(files)
    for file_name in files:
        abs_path = os.path.abspath(file_name)
        if os.path.isdir(abs_path):
            getfiles(abs_path)
        if os.path.isfile(abs_path):
            f = open(file_name, "r")
            if text in f.read():
                f = 1
                print(text + " found in ")
                final_path = os.path.abspath(file_name)
                print(final_path)
                print('hello!')
                return True

    if f == 1:
        print(text + " not found! ")
        return False


getfiles(path)
# Out:
# input text : Hello
# path : /content

# %%
print(getfiles(path))
# Out:
# None

# %% [markdown]
# #3 - Encrypt A String To Generate A Password

# %%
#import Libraries
import random
import string

# %%
#Create a randomly encrypted pasword
total = string.ascii_letters + string.digits + string.punctuation

length = 16

password = "".join(random.sample(total, length))

print(password)
# Out:
# IWKsv0?M%PS$6cZ[

# %% [markdown]
# #4 - Encrypt A Secret Message

# %%
# Assign the alphabet to a variable
# Assign the key to a variable
# Create an emply string
alphabet = 'abcdefghijklmnopqrstuvwxyz'
key = 3
newMessage = ' '

message = input('Please enter a message: ')

# Create a function that takes our message and swaps each charter based on the key
for character in message:
    position = alphabet.find(character)
    newPosition = (position + key) % 26
    newCharacter = alphabet[newPosition]
    newMessage += newCharacter
    

print(newMessage)
# Out:
# Please enter a message: hello world
#  khoorczruog

# %% [markdown]
# #5 - Bulk Rename Files

# %%
#Find out what the current directory is
os.getcwd()
# Out:
# '/content/.config/configurations'

# %%
#Import Library
import os

# %%
# Create a function to bult rename files
def main():
    i = 0
    path = "/content/"
    for filename in os.listdir(path):
        my_dest = "img" + str(i) + ".png"
        my_source = path + filename
        my_dest = path + my_dest
        os.rename(my_source, my_dest)
        i += 1

if __name__ == '__main__':

#Call main() function
    main()

# %% [markdown]
# #6 - Word Guessing

# %%
#Import the library
import random

# %%
#Ask the user for their input and assign it to a variable

name = input("What is your name? ")

print("Good Luck!", name)

#Create a list of words

words = ["blueberry", "grape", "apple", "mango", "watermellon"]

#Randomly select a word

word = random.choice(words)

#Ask the user to guess the word

print("Guess the characters")

#Create a variable that will hold the letters guessed
guesses = ''

#Create a variable that determines the number of guesses allowed

turns = 12

#Create a while loop that takes and prints the letter and returns whether the letter is right or wrong

while turns > 0:
    failed = 0

    for char in guesses:
        print(char)

    else:
        print("_")

        failed += 1

    if failed == 0:
        print("You win!")

        print("This word is ", word)
        break

    guess = input("guess a character: ")

    guesses += guess

    #Create a loop that tells the user whether they have passed or failed the game

    if guess not in word:
        turns -= 1
        print("Wrong")

        print("You have", + turns, "more guesses")

        if turns == 0:
            print("You Loose")

# %% [markdown]
# #7 - Reverse A List Of Strings

# %%
#Assign a list of strings to a variable and use .reverse() to reverse the list of strings
names = ['Paul', 'Jane', 'Sandra', 'Gemma', 'Hannah', 'Anne']
print(names)
names.reverse()
print(names)
# Out:
# ['Paul', 'Jane', 'Sandra', 'Gemma', 'Hannah', 'Anne']
# ['Anne', 'Hannah', 'Gemma', 'Sandra', 'Jane', 'Paul']

# %% [markdown]
# #8 - Reverse A String

# %%
#Assign a string to a variable and use slicing to print the values between given indices
name = 'natalie'

# %%
name = 'natalie' [::-1]

# %%
print(name)
# Out:
# eilatan

# %% [markdown]
# #9 - Acronym Generator

# %%
#Accept an input and save it to the text variable. Split the input string.
user_input = str(input("Enter a Phrase: "))
text = user_input.split()
a = " "

#Loop through input and split it where there is a space in the phrase, capitalise every word's first letter, and print the acronym.
for i in text:
    a = a+str(i[0]).upper()
print(a)
# Out:
# Enter a Phrase: Have fun coding
#  HFC

# %% [markdown]
# #10 - Generate A Story

# %%
#import the library
import random

# %%
#Assign a list of a part of the story to a variable
when = ['A few years ago', 'Yesterday', 'Last night', 'A long time ago','On 1st Jan', 'Once upon a time', 'Before man walked the earth']
who = ['a rabbit', 'an elephant', 'a mouse', 'a turtle','a cat', 'a chicken', 'a butterfly', 'an ant']
name = ['Natasha', 'Ben', 'Casandra', 'Emily', 'Sam', 'George', 'Carmel']
residence = ['Spain','Russia', 'Germany', 'Venice', 'England', 'Ireland', 'Scotland', 'Wales', 'France', 'Italy', 'Austria']
went = ['cinema', 'laundry', 'party', 'mountains', 'lake', 'funfare', 'circus', 'zoo']
happened = ['made a lot of friends','Eats a burger', 'found a secret key', 'solved a mistery', 'wrote a book']

# %%
# Print the variable in a logical order
print(random.choice(when) + ', ' + random.choice(who) + ' that lived in ' + random.choice(residence) + ', went to the ' + random.choice(went) + ' and ' + random.choice(happened) + '.')
# Out:
# Before man walked the earth, an elephant that lived in Germany, went to the circus and made a lot of friends.

# %% [markdown]
# #11 - Rotate A String

# %%
# Assign a string to a variable
s = "100 Python projects"

# %%
#Rotate the string - move each character 3 indices  to the right
s[-3:] + s[:-3]
# Out:
# 'cts100 Python proje'

# %%
#Rotate the string - move each character 3 indices  to the right
from collections import deque
d = deque(s)
d.rotate(3)

d

# %%
"".join(d)
# Out:
# 'cts100 Python proje'

# %% [markdown]
# #12 - Sort A String

# %%
#Assign a string to a variable
print()
message = 'Welcome to my humble abode!'
number = '192746'

#Print the string
print(message)
print(number)

#Sort the string
message_sorter = sorted(message)
number_sorted = sorted(number)

#Print each character in the sorted string
print(message_sorter)
print(number_sorted)

#Assign a string to a variable. Sort the string. Print the sorted string
print('Sort strings by words:')
message_sorter_word = sorted(message.split())
print(message_sorter_word)
# Out:
# Welcome to my humble abode!
# 192746
# [' ', ' ', ' ', ' ', '!', 'W', 'a', 'b', 'b', 'c', 'd', 'e', 'e', 'e', 'e', 'h', 'l', 'l', 'm', 'm', 'm', 'o', 'o', 'o', 't', 'u', 'y']
# ['1', '2', '4', '6', '7', '9']
# Sort strings by words:
# ['Welcome', 'abode!', 'humble', 'my', 'to']

# %% [markdown]
# #13 - Recreate A Story Using Formatting and String Replacement

# %%
#import Library
import re
from random import choice
import requests

# %%
#Extract the story from the URL
url = "https://www.gutenberg.org/files/1342/1342-0.txt"
r = requests.get(url)
text = r.text

# %%
#Print out the original text
print(text)

# %%
#Create a function that replaces particular words in the story

def change_prose(text):
    plural_nouns = ['ladies', 'gentlemen', 'women', 'men', 'children', 'boys', 'girls']

    singular_nouns = ['son', 'daughter', 'child','wife', 'woman', 'mrs', 'miss','husband', 'man', 'mr', 'sir', 'lady']

    speaking = ['said', 'replied', 'spoke', 'shouted', 'cried']
    zombie_sounds = ['groaned', 'moaned' ,'growled', 'screamed', 'gurgled']

    plural_nouns = plural_nouns + [word.title() for word in plural_nouns]
    singular_nouns = singular_nouns + [word.title() for word in singular_nouns]


    for word in plural_nouns:
        text = re.sub(r'\b{0}\b'.format(word), 'zombies', text)
    for word in singular_nouns:
        text = re.sub(r'\b{0}\b'.format(word), 'zombie', text)
    for word in speaking:
        text = re.sub(r'\b{0}\b'.format(word), choice(zombie_sounds), text)
    return(text)

text = change_prose(text)

with open('Zombie.txt', 'w', encoding="utf-8") as f:
    f.write(text)

# %%
print(text)

# %% [markdown]
# #14 - Match A String

# %%
#Compare two strings
Str1 = "Apple Inc."
Str2 = "Apple Inc."
Result = Str1 == Str2
print(Result)
# Out:
# True

# %%
#Compare two strings with different cases
tr1 = "Apple Inc."
Str2 = "apple Inc."
Result = Str1 == Str2
print(Result)
# Out:
# False

# %%
#Convert strings and the compare strings
Str1 = "Apple Inc."
Str2 = "apple Inc."
Result = Str1.lower() == Str2.lower()
print(Result)
# Out:
# True

# %%
#Compare strings using the Levenshtein Distance method

#Import Library
import numpy as np

#Create a definition that calculates levenshtein distance between two strings
def levenshtein_ratio_and_distance(s, t, ratio_calc = False):
    """ Levenshtein_ratio_and_distance:
        Calculates Levenshtein distance between two strings.
        If ratio_calc = True, the function computes the
        Levenshtein distance ratio of similarity between two strings
        For all i and j, distance[i,j] will contain the Levenshtein
        distance between the first i characters of s and the
        first j characters of t
    """
    # Initialize matrix of zeros
    rows = len(s)+1
    cols = len(t)+1
    distance = np.zeros((rows,cols),dtype = int)

    # Populate matrix of zeros with the indeces of each character of both strings
    for i in range(1, rows):
        for k in range(1,cols):
            distance[i][0] = i
            distance[0][k] = k

    # Iterate over the matrix to compute the cost of deletions,insertions and/or substitutions    
    for col in range(1, cols):
        for row in range(1, rows):
            if s[row-1] == t[col-1]:
                cost = 0 # If the characters are the same in the two strings in a given position [i,j] then the cost is 0
            else:
                # In order to align the results with those of the Python Levenshtein package, if we choose to calculate the ratio
                # the cost of a substitution is 2. If we calculate just distance, then the cost of a substitution is 1.
                if ratio_calc == True:
                    cost = 2
                else:
                    cost = 1
            distance[row][col] = min(distance[row-1][col] + 1,      # Cost of deletions
                                 distance[row][col-1] + 1,          # Cost of insertions
                                 distance[row-1][col-1] + cost)     # Cost of substitutions
    if ratio_calc == True:
        # Computation of the Levenshtein Distance Ratio
        Ratio = ((len(s)+len(t)) - distance[row][col]) / (len(s)+len(t))
        return Ratio
    else:
        # print(distance) # Uncomment if you want to see the matrix showing how the algorithm computes the cost of deletions,
        # insertions and/or substitutions
        # This is the minimum number of edits needed to convert string a to string b
        return "The strings are {} edits away".format(distance[row][col])

# %%
#Create the strings and compare them
Str1 = "Apple Inc."
Str2 = "apple Inc"
Distance = levenshtein_ratio_and_distance(Str1,Str2)
print(Distance)
Ratio = levenshtein_ratio_and_distance(Str1,Str2,ratio_calc = True)
print(Ratio)
# Out:
# The strings are 2 edits away
# 0.8421052631578947

# %%
Str1 = "Apple Inc."
Str2 = "apple Inc"
Distance = levenshtein_ratio_and_distance(Str1.lower(),Str2.lower())
print(Distance)
Ratio = levenshtein_ratio_and_distance(Str1.lower(),Str2.lower(),ratio_calc = True)
print(Ratio)
# Out:
# The strings are 1 edits away
# 0.9473684210526315

# %% [markdown]
# #15 - Extract Strings Between HTML Tags

# %%
# importing re module
import re
  
# initializing string
test_str = '<b>Gfg</b> is <b>Best</b>. I love <b>Reading CS</b> from it.'
  
# printing original string
print("The original string is : " + str(test_str))
  
# initializing tag
tag = "b"
  
# regex to extract required strings
reg_str = "<" + tag + ">(.*?)</" + tag + ">"
res = re.findall(reg_str, test_str)
  
# printing result
print("The Strings extracted : " + str(res))
# Out:
# The original string is : <b>Gfg</b> is <b>Best</b>. I love <b>Reading CS</b> from it.
# The Strings extracted : ['Gfg', 'Best', 'Reading CS']

# %% [markdown]
# #16 - Find Indices of Overlapping Substrings

# %%
# Import required module
import re
  
  
# Function to depict use of finditer() method
def CntSubstr(pattern, string):
  
    # Array storing the indices
    a = [m.start() for m in re.finditer(pattern, string)]
    return a
  
  
# Driver Code
string = 'natashalikespythonlikepython'
pattern = 'natashalikespython'
  
# Printing index values of non-overlapping pattern
print(CntSubstr(pattern, string))
# Out:
# [0]

# %% [markdown]
# #17 - Loop Through A String

# %%
#Loop through a string and print each letter on a new line
for x in 'Python':
  print(x)
# Out:
# P
# y
# t
# h
# o
# n

# %% [markdown]
# #18 - Find The Length Of A String

# %%
#Use len() to check the length of a string
x = 'Python or SQL'
print(len(x))
# Out:
# 13

# %% [markdown]
# #19 - Check A String

# %%
#Check if a given alphanumeric value is in a string
y = 'Never stop learning because life never stops teaching'
print('life' in y)
# Out:
# True

# %% [markdown]
# #20 - Slicing Strings

# %%
#Assign a string to a variable and use slicing the select the values between given indices
z = 'The capacity to learn is a girft;the ability to learn is a skill; the willingness to learn is a choice.'
print(z[3:12])
# Out:
#  capacity

# %%
print(z[:12])
# Out:
# The capacity

# %%
print(z[12:])
# Out:
#  to learn is a girft;the ability to learn is a skill; the willingness to learn is a choice.

# %% [markdown]
# #21 - Modify A String

# %%
# Return the string in lower case
txt = 'Learning is a constant process of discovery'
print(txt.lower())
# Out:
# learning is a constant process of discovery

# %%
# Return the string in upper case
txt = 'Learning is a constant process of discovery'
print(txt.upper())
# Out:
# LEARNING IS A CONSTANT PROCESS OF DISCOVERY

# %%
#Remove whitespace
txt = 'Learning is a constant process of discovery.   '
print(txt.strip())
# Out:
# Learning is a constant process of discovery.

# %%
#Repace letters in a string
txt = 'Learning is a constant process of discovery'
print(txt.replace('L', ' '))
# Out:
#  earning is a constant process of discovery

# %% [markdown]
# #22 - String Concatenation

# %%
#Create two separate strings and add them together using +
n = 'Learning a new thing '
a = 'EVERYDAY!'
t = n + a
print(t)
# Out:
# Learning a new thing EVERYDAY!

# %%
s = 'Learning is the treasure that'
h = ' '
w = 'will follow its owner everywhere!'
b = s + h + w
print(b)
# Out:
# Learning is the treasure that will follow its owner everywhere!

# %% [markdown]
# #23 - Count The Number Of Vowels In A String

# %%
#Create a function that checks if a string sontains a vowel
def vowel (word):
  count = 0
  vowel = set('aeiouAEIOU')

  for char in word:
    if char in vowel:
      count = count + 1

  print('The number of vowels in this string: ', count)

word = 'Learning a new thing everyday.'
print(vowel(word))
# Out:
# The number of vowels in this string:  9
# None

# %% [markdown]
# #24 - Convert A String To A Dictionary

# %%
#Assign the strings to variables
txt1 = 'One, Two, Three, Four'
txt2 = 'A, B, C, D'

# %%
#Split the strings
keys = txt1.split(',')
values = txt2.split(',')

# %%
#Create an empty dictionary
dictionary = {}

# %%
#
for i in range(len(keys)):
  dictionary[keys[i]] = values[i]

print(dictionary)
# Out:
# {'One': 'A', ' Two': ' B', ' Three': ' C', ' Four': ' D'}

# %% [markdown]
# #25 - Check If A String Has At Least A Letter or Number

# %%
#Define a function that tests if a string has a letter or number
def chkStr(string):
  chk1 = False
  chk2 = False

  for i in string:

#check if the string has a letter
    if i.isalpha():
      chk1 = True

#check if the string has a digit
    if i.isdigit():
      chk2 = True

  return chk1 and chk2

print(chkStr('thisisastring123'))
print(chkStr('thisisalsoastring'))
# Out:
# True
# False

# %% [markdown]
# #26 - Remove Empty Spaces In A String

# %%
# Assign the list of strings to a variable and print the list
string = ['abc', ' ', '  ', 'def', '  ', ' ', 'ghi'] 
print('The original string: ', str(string))
# Out:
# The original string:  ['abc', ' ', '  ', 'def', '  ', ' ', 'ghi']

# %%
#Create an empty list that stores the new list of strings
#Loop through the list of strings and remove empty strings
res = []
for var in string:
  if var.strip():
    res.append(var)

print('The new string: ', str(res))
# Out:
# The new string:  ['abc', 'def', 'ghi']

# %% [markdown]
# #27 - Document Your Code

# %%
#Use a docstring to document code
'''This is some docstring that documents my code,
it can be a single line or on multiple lines, 
it helps to make your code understandable'''


x = 'Python'
print(x)
# Out:
# Python

# %% [markdown]
# #28 - Find Out What Letter A String Starts With

# %%
#Assign a string to a variable and find out if the string starts with a given substring
string1 = '50 String Coding Questions Using Python'
result1 = string1.startswith('50 String')
result2 = string1.startswith('Hellow World')
print(result1)
print(result2)
# Out:
# True
# False

# %% [markdown]
# #29 - Find Out What Letter A String Ends With

# %%
#Assign a string to a variable and find out if the string ends with a given substring
string2 = '50 String Coding Questions Using Python'
result1 = string2.endswith('Python')
result2 = string2.endswith('Hellow World')
print(result1)
print(result2)
# Out:
# True
# False

# %% [markdown]
# #30 - Return A List Of Strings From a Multiline String

# %%
#Assign a multiline string to a variable
string3 = '''
100 Projects For Beginners Using Python,
Predict Rocket Launch Delays With Machine Learning And Python,
Creating A WordCloud Using Python,
Automate Text Messages Using Python,
The Beginners Guide To Extracting COBie Data — Part 1'''

#use splitlines() to assign each line as a value in a list

z = string3.splitlines()
print(string3)
print('\n')
print(z)
# Out:
# 100 Projects For Beginners Using Python,
# Predict Rocket Launch Delays With Machine Learning And Python,
# Creating A WordCloud Using Python,
# Automate Text Messages Using Python,
# The Beginners Guide To Extracting COBie Data — Part 1
#
#
# ['', '100 Projects For Beginners Using Python,', 'Predict Rocket Launch Delays With Machine Learning And Python,', 'Creating A WordCloud Using Python,', 'Automate Text Messages Using Python,', 'The Beginners Guide To Extracting COBie Data\u200a—\u200aPart 1']

# %% [markdown]
# #31 - Convert A String To An Int or Float

# %%
#Assign a string to a variable and convert the string to an integer using int()

xyz = '123456'
abc = int(xyz)

print(xyz)
print(abc)
# Out:
# 123456
# 123456

# %% [markdown]
# #32 - Generate A Poem

# %%
#Import library
import random

# %%
#Assign parts of a sentence to a variable

when = ['A few years ago', 'Yesterday', 'Last night', 'A long time ago','On 1st Jan', 'Once upon a time', 'Before man walked the earth']
who = ['a rabbit', 'an elephant', 'a mouse', 'a turtle','a cat', 'a chicken', 'a butterfly', 'an ant']
name = ['Natasha', 'Ben', 'Casandra', 'Emily', 'Sam', 'George', 'Carmel']
residence = ['Spain','Russia', 'Germany', 'Venice', 'England', 'Ireland', 'Scotland', 'Wales', 'France', 'Italy', 'Austria']
went = ['cinema', 'laundry', 'party', 'mountains', 'lake', 'funfare', 'circus', 'zoo']
happened = ['made a lot of friends','Eats a burger', 'found a secret key', 'solved a mistery', 'wrote a book']
rhyme1 = ['blue','clue','you','knew', 'who']
rhyme2 = ['flew', 'few', 'grew', 'do']
rhyme3 = ['Drew', 'Hu', 'Boo', 'Dulu']
like = ['a kangaroo', 'a buckaroo', ' a caribou', 'a cock-a-doodle-doo']

# %%
#Join and print the sentence parts

print(random.choice(when) + ', ' + 'When the wind still blew')
print('There was ' + random.choice(who) + ' and it was called Who')
print('It lived with ' + random.choice(who))
print('Whose name was ' + random.choice(rhyme3))
print('It lived with ' + random.choice(who) + ' who acted like ' + random.choice(like))
# Out:
# Before man walked the earth, When the wind still blew
# There was a rabbit and it was called Who
# It lived with a butterfly
# Whose name was Boo
# It lived with a butterfly who acted like a cock-a-doodle-doo

# %% [markdown]
# #33 - Read Information From A Wikipedia Page

# %%
#Import libraries
import urllib.request
from bs4 import BeautifulSoup
  
# here we have to pass url and path
# (where you want to save ur text file)
urllib.request.urlretrieve("https://en.wikipedia.org/wiki/Python_(programming_language)",
                           "text_file.txt")
  
file = open("text_file.txt", "r")
contents = file.read()
soup = BeautifulSoup(contents, 'html.parser')
  
f = open("text_file.txt", "w")
  
# traverse paragraphs from soup
for data in soup.find_all("p"):
    sum = data.get_text()
    f.writelines(sum)

# %%
f = open('text_file.txt', 'r')

# %%
file_contents = f.read()

# %%
print (file_contents)

# %% [markdown]
# #34 - Use Strings To Create Art (ACSII)

# %%
#Create ACSII art and assign it to a variable
camel = r"""
Switching on the camera in the camel habitat...
 ___.-''''-.
/___  @    |
',,,,.     |         _.'''''''._
     '     |        /           \
     |     \    _.-'             \
     |      '.-'                  '-.
     |                               ',
     |                                '',
      ',,-,                           ':;
           ',,| ;,,                 ,' ;;
              ! ; !'',,,',',,,,'!  ;   ;:
             : ;  ! !       ! ! ;  ;   :;
             ; ;   ! !      ! !  ; ;   ;,
            ; ;    ! !     ! !   ; ;
            ; ;    ! !    ! !     ; ;
           ;,,      !,!   !,!     ;,;
           /_I      L_I   L_I     /_I
Look at that! Our little camel is sunbathing!"""

# %%
#Create ACSII art and assign it to a variable
lion = r"""
Switching on the camera in the lion habitat...

 ,w.
                                             ,YWMMw  ,M  ,
                        _.---.._   __..---._.'MMMMMw,wMWmW,
                   _.-""        '''           YP"WMMMMMMMMMb,
                .-' __.'                   .'     MMMMW^WMMMM;
    _,        .'.-'"; `,       /`     .--""      :MMM[==MWMW^;
 ,mM^"     ,-'.'   /   ;      ;      /   ,       MMMMb_wMW"  @\
,MM:.    .'.-'   .'     ;     `\    ;     `,     MMMMMMMW `"=./`-,
WMMm__,-'.'     /      _.\      F'''-+,,   ;_,_.dMMMMMMMM[,_ / `=_}
"^MP__.-'    ,-' _.--""   `-,   ;       \  ; ;MMMMMMMMMMW^``; __|
           /   .'            ; ;         )  )`{  \ `"^W^`,   \  :
          /  .'             /  (       .'  /     Ww._     `.  `"
         /  Y,              `,  `-,=,_{   ;      MMMP`""-,  `-._.-,
        (--, )                `,_ / `) \/"")      ^"      `-, -;"\:
The lion is roaring!"""

# %%
#Create ACSII art and assign it to a variable
deer = r"""
Switching on the camera in the deer habitat...
   /|       |\
`__\\       //__'
   ||      ||
 \__`\     |'__/
   `_\\   //_'
   _.,:---;,._
   \_:     :_/
     |@. .@|
     |     |
     ,\.-./ \
     ;;`-'   `---__________-----.-.
     ;;;                         \_\
     ';;;                         |
      ;    |                      ;
       \   \     \        |      /
        \_, \    /        \     |\
          |';|  |,,,,,,,,/ \    \ \_
          |  |  |           \   /   |
          \  \  |           |  / \  |
           | || |           | |   | |
           | || |           | |   | |
           | || |           | |   | |
           |_||_|           |_|   |_|
          /_//_/           /_/   /_/
Our 'Bambi' looks hungry. Let's go to feed it!"""

goose = r"""
Switching on the camera in the goose habitat...
                                    _
                                ,-"" "".
                              ,'  ____  `.
                            ,'  ,'    `.  `._
   (`.         _..--.._   ,'  ,'        \    \
  (`-.\    .-""        ""'   /          (  d _b
 (`._  `-"" ,._             (            `-(   \
 <_  `     (  <`<            \              `-._\
  <`-       (__< <           :
   (__        (_<_<          ;
    `------------------------------------------
The goose is staring intently at you... Maybe it's time to change the channel?"""

bat = r"""
Switching on the camera in the bat habitat...
_________________               _________________
 ~-.              \  |\___/|  /              .-~
     ~-.           \ / o o \ /           .-~
        >           \\  W  //           <
       /             /~---~\             \
      /_            |       |            _\
         ~-.        |       |        .-~
            ;        \     /        i
           /___      /\   /\      ___\
                ~-. /  \_/  \ .-~
                   V         V
This bat looks like it's doing fine."""

rabbit = r"""
Switching on the camera in the rabbit habitat...
         ,
        /|      __
       / |   ,-~ /
      Y :|  //  /
      | jj /( .^
      >-"~"-v"
     /       Y
    jo  o    |
   ( ~T~     j
    >._-' _./
   /   "~"  |
  Y     _,  |
 /| ;-"~ _  l
/ l/ ,-"~    \
\//\/      .- \
 Y        /    Y
 l       I     !
 ]\      _\    /"\
(" ~----( ~   Y.  )
It looks like we will soon have more rabbits!"""

# %%
#Create a list containing all the variables
list = [camel, lion, deer, goose, bat, rabbit]

# %%
#Create a while loop that asks the user to select a variable and prints the contents of the variable
while True:
    habitat = input('Please enter the number of the habitat you would like to view: ')


    if habitat != 'exit':
        habitat = int(habitat)
        view: str = list[habitat]
        print(view)

    else:
        print("See you later!")
        break
# Out:
# Please enter the number of the habitat you would like to view: 3
#
# Switching on the camera in the goose habitat...
#                                     _
#                                 ,-"" "".
#                               ,'  ____  `.
#                             ,'  ,'    `.  `._
#    (`.         _..--.._   ,'  ,'        \    \
#   (`-.\    .-""        ""'   /          (  d _b
#  (`._  `-"" ,._             (            `-(   \
#  <_  `     (  <`<            \              `-._\
#   <`-       (__< <           :
#    (__        (_<_<          ;
#     `------------------------------------------
# The goose is staring intently at you... Maybe it's time to change the channel?
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     728             try:
# ...

# %% [markdown]
# #35 - Create A Database

# %% [markdown]
# Place the following information into a .txt file and save it locally.
# Each line contains the following information: name, age, department, role
#
# Adam, 25, IT, Data Scientist
# Annie, 23, Marketing, Marketing Manager
# Ben, 28, IT, Data Analysis
# Betty, 30, IT, CTO
# Charlie,24, Marketing, Marketing Specialist
# Cathy, 32, IT, Data Analysis

# %%
#open the file and save it to the variable file
file = open('companyA.txt')

# %%
#print the contents of the file
print(file.read())
# Out:
# Adam, 25, IT, Data Scientist
# Annie, 23, Marketing, Marketing Manager
# Ben, 28, IT, Data Analysis
# Betty, 30, IT, CTO
# Charlie,24, Marketing, Marketing Specialist
# Cathy, 32, IT, Data Analysis

# %%
#close the file
file.close()

# %%
#Another way to loop through the file

#open the file and save it to the variable file
file = open('companyA.txt')

#read the file
for line in file.read().splitlines():
  print(line)
  

#close the file
file.close()
# Out:
# Adam, 25, IT, Data Scientist
# Annie, 23, Marketing, Marketing Manager
# Ben, 28, IT, Data Analysis
# Betty, 30, IT, CTO
# Charlie,24, Marketing, Marketing Specialist
# Cathy, 32, IT, Data Analysis

# %% [markdown]
# #36 - Visualise String Data

# %%
#Install the wikipedia library locally
# !pip install wikipedia

# %%
#import libraries
import wikipedia
from wordcloud import WordCloud, STOPWORDS
# Pandas for file reading/ visualize data
import pandas as pd
import seaborn as sns
import numpy as np
from PIL import Image
#Matplot to visualize data, also Seaborn and pandas do this
import matplotlib.pyplot as plt
# Inline to show images in jupyter notebook
# %matplotlib inline
import re

# %%
# Define a function to plot word cloud
def plot_cloud(wordcloud):
    # Set figure size
    plt.figure(figsize=(40, 30))
    # Display image
    plt.imshow(wordcloud) 
    # No axis details
    plt.axis("off");

# %%
# Specify the title of the Wikipedia page
wiki = wikipedia.page("William Shakespeare")
# Extract the plain text content of the page
text = wiki.content
# Clean text
text = re.sub(r'==.*?==+', '', text)
text = text.replace('\n', '')

# %%
# Generate word cloud with a dark background
wordcloud = WordCloud(width= 3000, height = 2000, random_state=1, background_color='#73B8E9', colormap='Pastel1', collocations=False, stopwords = STOPWORDS).generate(text)
# Plot
plot_cloud(wordcloud)

# %% [markdown]
# #37 - Create A Bot

# %%
#Create a function that allows the bot introduce itself
def greet(bot_name, birth_year):
    print('Hello! My name is ' + bot_name + '.')
    print('I was created in ' + birth_year + '.')

#Create a function that allows the user introduce itself to the bot
def remind_name():
    print('Please, remind me your name.')
    name = input()
    print('What a great name you have, ' + name + '!')

#Create a function that guesses the users name
def guess_age():
    print('Let me guess your age.')
    print('Enter remainders of dividing your age by 3, 5 and 7.')

    rem3 = int(input())
    rem5 = int(input())
    rem7 = int(input())
    age = (rem3 * 70 + rem5 * 21 + rem7 * 15) % 105

    print("Your age is " + str(age) + "; that's a good time to start programming!")

#Create a function that teaches the bot to count
def count():
    print('Now I will prove to you that I can count to any number you want.')

    num = int(input())
    curr = 0
    while curr <= num:
        print(curr, '!')
        curr = curr + 1

#Create a function that teaches the bot to test the users programming knowledge
def test():
    print("Let's test your programming knowledge.")

    print('Why do we use methods?')
    print('1. To repeat a statement multiple times.')
    print('2. To decompose a program into several small subroutines.')
    print('3. To determine the execution time of a program.')
    print('4. To interrupt the execution of a program.')

    possible_answer = 0
    while possible_answer != 2:
        possible_answer = int(input())
        if possible_answer != 2:
            print('Please, try again.')


def end():
    print('Congratulations, have a nice day!')


greet('Aid', '2020')
remind_name()
guess_age()
count()
# ...
test()
end()
# Out:
# Hello! My name is Aid.
# I was created in 2020.
# Please, remind me your name.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     728             try:
# --> 729                 ident, reply = self.session.recv(self.stdin_socket, 0)
#     730             except Exception:
#
# /usr/local/lib/python3.7/dist-packages/jupyter_client/session.py in recv(self, socket, mode, content, copy)
#     802         try:
# --> 803             msg_list = socket.recv_multipart(mode, copy=copy)
#     804         except zmq.ZMQError as e:
#
# /usr/local/lib/python3.7/dist-packages/zmq/sugar/socket.py in recv_multipart(self, flags, copy, track)
#     723         """
# --> 724         parts = [self.recv(flags, copy=copy, track=track)]
# ...

# %% [markdown]
# # 38 - Return The Highest Index Of A String

# %%
#Take a string a locate the index of the substring
string1 = 'This is a string'
result = string1.rfind('This')
result2 = string1.rfind('string')
print('The substring "This" is found at index: ', result)
print('The substring "string" is found at index: ', result2)
# Out:
# The substring "This" is found at index:  0
# The substring "string" is found at index:  10

# %% [markdown]
# # 39 - Return A String After Substitution To The Left Or Right Side

# %%
#Take a string and give it a new length, substituting the spaces with a given symbol/char/number
txt1 = 'Python'
length = 10
fillchar = '#'

print(txt1.rjust(length, fillchar))
# Out:
# ####Python

# %%
txt1 = 'Python'
length = 10
fillchar = '#'

print(txt1.ljust(length, fillchar))
# Out:
# Python####

# %% [markdown]
# # 40 - Use Encode() To Encode A String

# %%
#Load the library
from encodings.aliases import aliases

# %%
#Print the encodings
print('Available Encodings: ')
print(aliases.keys())
# Out:
# Available Encodings:
# ...

# %%
#returns the encoded string and ignores uncodable unicode
string4 = 'Python'
print(string4.encode('utf8', 'ignore'))
print(string4.encode('u8', 'ignore'))
# Out:
# b'Python'
# b'Python'

# %% [markdown]
# # 41 - Pad The leftside of A String With 0s

# %%
#Add 0's to the leftside of a string using .zfill() and assign it to the variable txt3. Print the variable. 
txt3 = '1234'
print(txt3.zfill(10))
# Out:
# 0000001234

# %% [markdown]
# # 42 - Check Whether A String Is A Valid Identifier

# %%
#Assign strings to variables - two contain numbers and one contains letters.
stringA = 'IdentifierA'
stringB = 'IdentifierA000'
stringC = '000IdentifierA'

#Check if the string is a valid identifier
print(stringA.isidentifier())
print(stringB.isidentifier())
print(stringC.isidentifier())
# Out:
# True
# True
# False

# %% [markdown]
# # 43 - Specify The Space In A String

# %%
#Assign a string with tabs to a variable and print the variable
txt5 = 'Python\tis\ta\tgreat\tlanguage'
print(txt5.expandtabs())
# Out:
# Python  is      a       great   language

# %%
#use .expandtabs() to create spaces where the tabs are located
txt5 = 'Python\tis\ta\tgreat\tlanguage'
print(txt5.expandtabs(2))
# Out:
# Python  is  a great language

# %%
#use .expandtabs() and pass a number in the parameter to create spaces with a certina distance
txt5 = 'Python\tis\ta\tgreat\tlanguage'
print(txt5.expandtabs(5))
# Out:
# Python    is   a    great     language

# %% [markdown]
# # 44 - Convert An Image Into A String

# %%
#Import a library
import base64

# %%
#Convert an image to a string using the base64 library
with open('test.jpg', 'rb') as image1:
  converted = base64.b64encode(image1.read())
print(converted)

with open('test.jpg', 'wb') as file:
  file.write(converted)
# Out:
# b'...'

# %% [markdown]
# # 45 - Change Data Types To Strings

# %%
#Assign an integer to a variable and print the variable's type
number = 12345678
print(type(number))
# Out:
# <class 'int'>

# %%
#Convert the integer to a string and print the variable's type
string = str(number)
print(type(string))
# Out:
# <class 'str'>

# %%
#Assign an float to a variable and print the variable's type
floatnumber = 12345.12345
print(type(floatnumber))
# Out:
# <class 'float'>

# %%
#Convert the float to a string and print the variable's type
stringAA = str(floatnumber)
print(type(stringAA))
# Out:
# <class 'str'>

# %% [markdown]
# # 46 - Remove Numerical Values From A String

# %%
#Assign a string to a variable and print the original string
intString = 'Go For It 100!'
print(intString)
# Out:
# Go For It 100!

# %%
#Loop through the string to find and remove numerical values and assign it to a new variable. Print the new variable. 
newString = ''.join([i for i in intString if not i.isdigit()])
print(newString)
# Out:
# Go For It !

# %% [markdown]
# # 47 - Check If A String Is A Keyword

# %%
#import the library
import keyword

# %%
#print the list of python keywords from the library
keyword_A = keyword.kwlist
print(keyword_A)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
#Create a function that checks if a string is a keyword
def checkKeyword(string1):

  keyword_A = keyword.kwlist

  if string1 in keyword_A:
    return 'Yes'
  else:
    return 'No'

# %%
if __name__ == '__main__':
  print(checkKeyword('hello world'))
  print(checkKeyword('True'))
# Out:
# No
# Yes

# %% [markdown]
# # 48 - Find Strings That Are A Certain Length

# %%
#Create a function that takes two arguments - a length and a string - and checks if the string is more significant than the length.
def string_num(a, str1):

  stringA = []

  txt1 = str1.split(' ')

  for i in txt1:

    if len(i) > a:

      stringA.append(i)

  return stringA

#Assign the length to the variable a
a = 4

#Assign the string to the variable str1
str1 = 'Python'
print(string_num(a, str1))
# Out:
# ['Python']

# %% [markdown]
# # 49 - Remove Consecutive Duplicates In A String

# %%
#Import libraries
import itertools
from itertools import groupby

# %%
#Assign a list of integers and strings to variables
num1 = [11, 11, 22, 33, 33, 44, 55, 66]
let1 = ['A', 'A', 'B', 'C', 'D', 'E', 'E', 'E', 'F', 'G']

# %%
#Create a for loop that iterates through the list and groups similar integers of strings
for i, group in itertools.groupby(num1):
  print(i, list(group))
# Out:
# 11 [11, 11]
# 22 [22]
# 33 [33, 33]
# 44 [44]
# 55 [55]
# 66 [66]

# %%
#Create a for loop that iterates through the list and groups similar integers of strings
for i, group in itertools.groupby(let1):
  print(i, list(group))
# Out:
# A ['A', 'A']
# B ['B']
# C ['C']
# D ['D']
# E ['E', 'E', 'E']
# F ['F']
# G ['G']

# %%
#Create a function that removes duplicated values from the list of integers or strings
def rem(input):
  result = []

  for i, group in groupby(input):
    result.append(i)

  print(''.join(result))

if __name__ == '__main__':
  input = 'aabcdeeefg'
  rem(input)
# Out:
# abcdefg

# %%
#Create a function that removes duplicated values from the list of integers or strings
def rem(input):
  result = []

  for i, group in groupby(input):
    result.append(i)

  print(''.join(result))

if __name__ == '__main__':
  input = '11, 11, 22, 33, 33, 44, 55, 66'
  rem(input)
# Out:
# 1, 1, 2, 3, 3, 4, 5, 6

# %% [markdown]
# # 50 - Check If A String Is A Palindrome

# %%
#Create a definition that retruns the reversed string
def palindrome(p):
  return p == p[::-1]

#Assign the string to the variable p and assign the function to the variable q.
p = 'Python'
q = palindrome(p)

#Use an If/Else statement to check if the string is a palindrome based on q.
if  q:
  print('Yes, this string is a palindrome.')

else:
  print('No, this string is not a palindrome.')
# Out:
# No, this string is not a palindrome.
